# %% [markdown]
# 1 . Import Libraries and Set Up API Key

# %%
import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries


api_key = 'YOUR_API_KEY'
ts = TimeSeries(key=api_key, output_format='pandas')

# %% [markdown]
# 2. Fetch Real-Time Stock Data

# %%
# Fetch intraday data with a 1-minute interval
data, meta_data = ts.get_intraday(symbol='AMZN', interval='1min', outputsize='full')

# Display the first few rows of the data
print(data.head())
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2024-08-12 19:59:00  166.788  166.788  166.70   166.740      349.0
# 2024-08-12 19:58:00  166.710  166.790  166.70   166.745      460.0
# 2024-08-12 19:57:00  166.720  166.790  166.70   166.710      409.0
# 2024-08-12 19:56:00  166.800  166.800  166.70   166.800      454.0
# 2024-08-12 19:55:00  166.765  166.810  166.71   166.750      633.0

# %% [markdown]
# 3. Visualize the Data

# %%
# Plot the closing prices
plt.figure(figsize=(14, 7))
plt.plot(data.index, data['4. close'], label='Close Price')
plt.title('Amazon (AMZN) Intraday Closing Prices')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()
